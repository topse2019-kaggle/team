# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
id = '1E2IWGQgc8IgWkQvOctYpwzkZhhXzU7Tq'  # 共有リンクで取得した id= より後の部分
downloaded = drive.CreateFile({'id': id})
downloaded.GetContentFile('lib.zip')

# %%
import os
# フォルダ「data」が存在しない場合は作成する
data_dir = "./lib/"
if not os.path.exists(data_dir):
    os.mkdir(data_dir)

# %%
    import zipfile

    save_path = "lib.zip"
    
    # ZIPファイルを読み込み
    zip = zipfile.ZipFile(save_path)
    zip.extractall("lib")  # ZIPを解凍
    zip.close()  # ZIPファイルをクローズ

    # ZIPファイルを消去
    os.remove(save_path)

# %%
id = '1c1Ihr_uW39waLPXkQHWJ9vq-yPKYEqIb'  # 共有リンクで取得した id= より後の部分
downloaded = drive.CreateFile({'id': id})
downloaded.GetContentFile('animals10.zip')

# %%
import os
# フォルダ「data」が存在しない場合は作成する
data_dir = "./data/"
if not os.path.exists(data_dir):
    os.mkdir(data_dir)

# %%
    import zipfile

    save_path = "animals10.zip"
    
    # ZIPファイルを読み込み
    zip = zipfile.ZipFile(save_path)
    zip.extractall("data")  # ZIPを解凍
    zip.close()  # ZIPファイルをクローズ

    # ZIPファイルを消去
    os.remove(save_path)

# %%
cd data/raw-img/
# Out:
# /content/data/raw-img

# %%
os.mkdir("./train/")
os.mkdir("./val/")

# %%
ls
# Out:
# cane/     elefante/  gallina/  mucca/   ragno/       train/
# cavallo/  farfalla/  gatto/    pecora/  scoiattolo/  val/

# %%
cd /content
# Out:
# /content

# %%
#データの件数確認

import glob
import shutil

foruda = os.listdir(path='.')
path = os.getcwd()  

for a in foruda:
# if a.find("-") != -1:
 if a != "train" and a != "val": #「train」、「val」フォルダ以外を対象にする
  files = os.listdir(path + "/" + a)  
  count = len(files)  
  print(a + ':' + str(count))
# Out:
# ragno:4821
# gallina:3098
# cavallo:2623
# pecora:1820
# scoiattolo:1862
# mucca:1866
# cane:4863
# gatto:1668
# elefante:1446
# farfalla:2112

# %%
ls
# Out:
# cane/     elefante/  gallina/  mucca/   ragno/       train/
# cavallo/  farfalla/  gatto/    pecora/  scoiattolo/  val/

# %%
#「/content/data/images/Images」以下の画像を「train」、「val」フォルダに振り分ける
# (もともフォルダ分けされているDataセットは不要)

import glob
import shutil

foruda = os.listdir(path='.')
path = os.getcwd()  

for a in foruda:
# if a.find("-") != -1:
 if a != "train" and a != "val": #「train」、「val」フォルダ以外を対象にする
  files = os.listdir(path + "/" + a)  
  count = len(files)  
  files = glob.glob("./"+a +"/*")
  i = 0
  for file in files:
    i = 1 + i
    if i < count*1/4:
     data_dir = "./val/" + a
     if not os.path.exists(data_dir):
      os.mkdir(data_dir)
     shutil.move(file, './val/'+ a + "/")
    else:
     data_dir = "./train/" + a
     if not os.path.exists(data_dir):
      os.mkdir(data_dir)
     shutil.move(file, './train/'+ a + "/")
  shutil.rmtree("./"+a)

# %%
cd ../val
# Out:
# /content/data/raw-img/val

# %%
#データの件数確認

import glob
import shutil

foruda = os.listdir(path='.')
path = os.getcwd()  

for a in foruda:
# if a.find("-") != -1:
 if a != "train" and a != "val": #「train」、「val」フォルダ以外を対象にする
  files = os.listdir(path + "/" + a)  
  count = len(files)  
  print(a + ':' + str(count))
# Out:
# ragno:1205
# gallina:774
# cavallo:655
# pecora:454
# scoiattolo:465
# mucca:466
# cane:1215
# gatto:416
# elefante:361
# farfalla:527

# %%
pwd
# Out:
# '/content/data/raw-img/val'

# %%
ls
# Out:
# adc.json  data/  lib/  sample_data/

# %% [markdown]
# *モデルの適用*

# %%
# %%time
! npm install -g localtunnel
# !python3 -m pip install visdom
# !python3 -m visdom.server -port 8076 >> visdomlog.txt 2>&1 &
# !lt --port 8076 >> url.txt 2>&1 &
# Out:
# /tools/node/bin/lt -> /tools/node/lib/node_modules/localtunnel/bin/lt.js
# + localtunnel@2.0.0
# added 35 packages from 21 contributors in 1.765s
# ...
#      |████████████████████████████████| 686kB 8.9MB/s
# ...
#      |████████████████████████████████| 204kB 58.7MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-cp36-none-any.whl size=655252 sha256=adccff34d808fb7be84fbb005695d9a5ca1d6fc1d74bf3476ab6112a02e38007
#   Stored in directory: /root/.cache/pip/wheels/70/19/a7/6d589ed967f4dfefd33bc166d081257bd4ed0cb618dccfd62a
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-cp36-none-any.whl size=5711 sha256=b6f2f17e39d4c6b9939da4e48030fdc9442d3cd5e0ef6094c280da329db6cc1a
#   Stored in directory: /root/.cache/pip/wheels/b1/c3/d6/9a1cc8f3a99a0fc1124cae20153f36af59a6e683daca0a0814
# Successfully built visdom torchfile
# ...
# CPU times: user 113 ms, sys: 69.7 ms, total: 183 ms
# Wall time: 18.4 s

# %%
# %%time
import time
time.sleep(5)
! cat url.txt
# Out:
# CPU times: user 13.5 ms, sys: 14.7 ms, total: 28.2 ms
# Wall time: 6.41 s

# %%
from lib.lib import network_finetuning as network
from lib.lib import architecture
from lib.lib import dataloader as dl
from lib.lib import optimizer
from lib.lib import trainer

import torchvision

# %%
# %%time
net = network.ResNet50(class_size=10)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
# ...

# %%
# %%time
batch_size = 128
train_dataset = torchvision.datasets.ImageFolder(root='./data/raw-img/train', transform=dl.simple_transform(resize=224))
test_dataset = torchvision.datasets.ImageFolder(root='./data/raw-img/val', transform=dl.simple_transform(resize=224))
data_loader = dl.DataLoader(train_dataset, test_dataset, batch_size=batch_size)
# Out:
# CPU times: user 68.5 ms, sys: 18.4 ms, total: 86.9 ms
# Wall time: 89.9 ms

# %%
# %%time
model = architecture.CNN_Architecture(net)
# Out:
# CPU times: user 2.77 ms, sys: 34 ms, total: 36.8 ms
# Wall time: 85.5 ms

# %%
# %%time
model.train(data_loader, epoch_count=50, is_inception=False)
# Out:
# cuda
# Setting up a new session...
# ----------
# Epoch 1/50 2020-01-27 06:48:14.944718
# val Loss: 7.2336 Acc: 0.0812
# ----------
# Epoch 2/50 2020-01-27 06:48:40.805861
# train Loss: 2.4065 Acc: 0.3517
# val Loss: 4.9815 Acc: 0.1660
# ----------
# Epoch 3/50 2020-01-27 06:52:31.524372
# train Loss: 2.2323 Acc: 0.2909
# val Loss: 3.6024 Acc: 0.1816
# ----------
# Epoch 4/50 2020-01-27 06:56:33.107118
# train Loss: 2.0464 Acc: 0.1893
# val Loss: 5.7592 Acc: 0.0716
# ----------
# Epoch 5/50 2020-01-27 07:00:33.680542
# train Loss: 2.0712 Acc: 0.3919
# val Loss: 2.5878 Acc: 0.1840
# ----------
# Epoch 6/50 2020-01-27 07:04:35.360609
# train Loss: 2.2597 Acc: 0.3190
# val Loss: 2.5259 Acc: 0.1843
# ----------
# Epoch 7/50 2020-01-27 07:08:36.771635
# train Loss: 2.0017 Acc: 0.4431
# val Loss: 2.7490 Acc: 0.1820
# ----------
# Epoch 8/50 2020-01-27 07:12:37.644303
# train Loss: 2.9510 Acc: 0.4200
# val Loss: 7.2271 Acc: 0.1843
# ----------
# Epoch 9/50 2020-01-27 07:16:38.619428
# ...

# %%
# %%time
model.predict(data_loader['val'])
# Out:
# 検証画像に対しての正解率： 49 %
# CPU times: user 278 ms, sys: 267 ms, total: 545 ms
# Wall time: 1.71 s
